# %%
import numpy as np
import os
import matplotlib.pyplot as plot
from PIL import Image, ImageOps
import cv2
from sklearn.cluster import KMeans
import random
## Selecting TensorFlow 2.0 - It's magic!
# %tensorflow_version 2.x  
import tensorflow as tf
from keras.models import Model, load_model
from keras.layers import Input, BatchNormalization, Conv2D, MaxPooling2D, Dense, Dropout, LeakyReLU, UpSampling2D, concatenate
from keras.optimizers import Adam, SGD
from keras.callbacks import ModelCheckpoint
import glob
from tqdm import tqdm_notebook

# %%
#!wget https://github.com/shubham0204/Dataset_Archives/blob/master/cityscape_images.zip?raw=true -O cityscape_images.zip
#!unzip cityscape_images.zip

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ls
# Out:
# drive  gdrive  sample_data

# %%
cd gdrive/
# Out:
# /content/gdrive

# %%
# !ls
# Out:
# 'My Drive'

# %%
cd My\ Drive
# Out:
# /content/gdrive/My Drive

# %%
# !ls
# Out:
#  20181128_165704.jpg
# 'Academic Flexibilities draft-1.docx'
# 'AE privinv datasheet.gsheet'
#  arl-eegmodels-master
# 'Arshika_Lalan_CV (1).pdf'
#  Arshika_Lalan_CV.pdf
# 'Arshika Lalan.jpg'
#  b.gdoc
#  BostonLinearRegression.ipynb
#  bostonlinearregression.py
#  CAA+NRC.gdoc
# 'Campus Ambassador.docx'
# 'Campus Ambassador.gdoc'
# 'Campus watch'
#  cityscapes-image-pairs
#  classifier.pt
#  Classroom
# 'Colab Notebooks'
# 'Contact Information.gform'
# 'Copy_of_qstp_assign1 - Arshika Lalan.ipynb'
#  Copy_of_qstp_assign1.ipynb
#  Coverage.gdoc
#  dataset_preprocessed.csv
#  dataset_preprocessed.gsheet
#  dataset_preprocessed.xlsx
#  DiabetesDataset.ipynb
#  diabetesdataset.py
# 'Document (9).docx'
#  dualite.docx
# 'EAPP Presentation PMFBY.gslides'
#  EEGModels.py
# 'EVS Chapter 21 Review.docx'
# 'EWB goa chapter.docx'
#  farewell.gdoc
#  FunctionalDependencies.gsheet
#  GPAfromSATScores.ipynb
#  gpafromsatscores.py
#  Gradesheet.pdf
# 'GuviCertification - 3T78iReBn885H05031.pdf'
# 'GuviCertification - 452321Im6x508e955p.pdf'
# 'GuviCertification - 45u5aK8j9T554b87c1.pdf'
# 'GuviCertification - 49D1n160597gf26z8J.pdf'
# 'GuviCertification - 58U4Rb3rT15h6X5j01.pdf'
# 'GuviCertification - h1801LQmgb566WA445.pdf'
# 'GuviCertification - V0495lK98U715k2219.pdf'
# 'Human Library.gdoc'
# 'Hyperloop India.docx'
# 'Hyperloop India.gdoc'
#  IMG20191225203436.jpg
#  IMG_20200404_151344.jpg
#  IrisDataset.ipynb
# 'l3fri1 (1).asm.gdoc'
#  l3fri1.asm.gdoc
# 'LDC prompt.docx'
# 'Lesson plan.gslides'
#  LoR_Arshika_Lalan
# 'LoR Arshika.pdf'
# 'MBFM Presentation (1).gslides'
# 'MBFM Presentation.gslides'
#  music
# 'My_CV (1).pdf'
#  Notes.gdoc
#  Photoessay.gdoc
# 'Piece (1).gdoc'
# 'Piece (2).gdoc'
# 'Piece (3).gdoc'
# 'Piece (4).gdoc'
#  Piece.gdoc
# 'PS1 presentation.gslides'
#  QSTP_DL_Completion_19.jpg
#  RBI_Article_Draft2.docx
# 'Reports for quark.gdoc'
#  Script.docx
#  Script.gdoc
# 'Section 377 (1).docx'
# 'Section 377.docx'
# 'Section 377.gdoc'
# 'Singapore '
# 'The Karan Singh magic transcript (1).gdoc'
# 'The Karan Singh magic transcript (2).gdoc'
# 'The Karan Singh magic transcript.gdoc'
#  TrendAnalysis.gsheet
# 'Untitled Diagram (1).drawio'
# 'Untitled Diagram (2).drawio'
# 'Untitled Diagram.drawio'
# 'Untitled document (1).gdoc'
# 'Untitled document (2).gdoc'
# 'Untitled document (3).gdoc'
# 'Untitled document.gdoc'
# 'Untitled presentation (1).gslides'
# 'Untitled presentation.gslides'

# %%
cd cityscapes-image-pairs/
# Out:
# /content/gdrive/My Drive/cityscapes-image-pairs

# %%
# !ls
# Out:
# cityscapes_data

# %%
cd cityscapes_data/
# Out:
# /content/gdrive/My Drive/cityscapes-image-pairs/cityscapes_data

# %%
# !ls
# Out:
# bas.png		 loss.h5     pred_1.png  pred_4.png  pred_7.png  train
# cityscapes_data  model.h5    pred_2.png  pred_5.png  pred_8.png  val
# learn.png	 pred_0.png  pred_3.png  pred_6.png  pred_9.png

# %%
train_path='train' #/content/gdrive/My Drive/cityscapes-image-pairs/cityscapes_data/train
val_path='val'

# %% [markdown]
# ##Loading the images

# %%
def LoadImage(name, path= train_path,
             rotation=0.0, flip=False, cut_bottom=58,
             size=(256, 200)):
    img = Image.open(path+"/"+name)
    img = np.array(img)
    seg = img[:-cut_bottom, 256:]
    img = img[:-cut_bottom, 0:256]
    
    for i in range(3):
        zimg = img[:,:,i]
        zimg = cv2.equalizeHist(zimg)
        img[:,:,i] = zimg
    
    img = Image.fromarray(img).resize(size)
    seg = Image.fromarray(seg).resize(size)
    
    

    img = img.rotate(rotation)
    seg = seg.rotate(rotation)

    img = np.array(img)
    seg = np.array(seg)

    if flip:
        img = img[:,::-1,:]
        seg = seg[:,::-1,:]
    
    return img/255, seg/255

# %% [markdown]
# ##K-Means Clustering

# %%
files =os.listdir(train_path)[0:10]

colors = []
for f in files:
    img, seg = LoadImage(f)
    colors.append(seg.reshape(seg.shape[0]*seg.shape[1], 3))
colors = np.array(colors)
colors = colors.reshape((colors.shape[0]*colors.shape[1],3))

km = KMeans(13)
km.fit(colors)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=13, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
def LayersToRGBImage(img):
    colors = [(255,0,0), (0,255,0), (0,0,255),
             (255,255,0), (255,0,255), (0,255,255),
             (255,255,255), (200,50,0),(50,200,0),
             (50,0,200), (200,200,50), (0,50,200),
             (0,200,50), (0,0,0)]
    
    nimg = np.zeros((img.shape[0], img.shape[1], 3))
    for i in range(img.shape[2]):
        c = img[:,:,i]
        col = colors[i]
        
        for j in range(3):
            nimg[:,:,j]+=col[j]*c
    nimg = nimg/255.0
    return nimg

# %%
def ColorsToClass(seg):
    s = seg.reshape((seg.shape[0]*seg.shape[1],3))
    s = km.predict(s)
    s = s.reshape((seg.shape[0], seg.shape[1]))
    
    n = len(km.cluster_centers_)
    
    cls = np.zeros((seg.shape[0], seg.shape[1], n))
    
    for i in range(n):
        m = np.copy(s)
        m[m!=i] = 0
        m[m!=0] = 1
        
        cls[:,:,i]=m
        
    return cls

img, seg = LoadImage("174.jpg")
seg2 = ColorsToClass(seg)
seg2 = LayersToRGBImage(seg2)
total = cv2.addWeighted(img, 0.6, seg2, 0.4, 0)
plot.imshow(total[:,:,:])
plot.show()

# %%
def Generate(path=train_path, batch_size=10,
            maxangle=10.0):
    
    files = os.listdir(path)
    while True:
        imgs=[]
        segs=[]
        
        for i in range(batch_size):
            file = random.sample(files,1)[0]
            
            flip=False
            if random.random() > 0.5:
                flip=True
            
            angle = maxangle*(random.random()*2-1)
            
            img, seg = LoadImage(file, path, rotation=angle, flip=flip)
            
            seg = ColorsToClass(seg)
            
            imgs.append(img)
            segs.append(seg)
        yield np.array(imgs), np.array(segs)
        
gen = Generate()
imgs, segs = next(gen)

plot.subplot(121)
plot.imshow(imgs[0])
plot.subplot(122)
plot.imshow(LayersToRGBImage(segs[0]))
plot.show()

# %%
inp = Input(shape=(200, 256, 3))

x1 = BatchNormalization()(inp)
x1 = Conv2D(64, 12, activation="relu", padding="same")(x1)
x1 = Conv2D(128, 12, activation="relu", padding="same")(x1)
p1 = MaxPooling2D()(x1)
#p1 = Dropout(0.2)(p1)

#x2 = BatchNormalization()(x1)
x2 = Conv2D(128, 9, activation="relu", padding="same")(p1)
x2 = Conv2D(128, 9, activation="relu", padding="same")(x2)
p2 = MaxPooling2D()(x2)
#p2 = Dropout(0.2)(p2)

#x3 = BatchNormalization()(x2)
x3 = Conv2D(128, 6, activation="relu", padding="same")(p2)
x3 = Conv2D(128, 6, activation="relu", padding="same")(x3)
p3 = MaxPooling2D()(x3)
#p3 = Dropout(0.2)(p3)

#x4 = BatchNormalization()(x3)
x4 = Conv2D(128, 3, activation="relu", padding="same")(p3)
x4 = Conv2D(128, 3, activation="relu", padding="same")(x4)
#x4 = MaxPooling2D()(x4)
#x4 = Dropout(0.2)(x4)

x5 = UpSampling2D()(x4)
x5 = concatenate([x3, x5])
x5 = Conv2D(128, 6, activation="relu", padding="same")(x5)
x5 = Conv2D(128, 6, activation="relu", padding="same")(x5)
#x5 = Dropout(0.2)(x5)

x6 = UpSampling2D()(x5)
x6 = concatenate([x2, x6])
x6 = Conv2D(128, 6, activation="relu", padding="same")(x6)
x6 = Conv2D(128, 6, activation="relu", padding="same")(x6)
#x6 = Dropout(0.2)(x6)

x7 = UpSampling2D()(x6)
x7 = concatenate([x1, x7])
x7 = Conv2D(13, 6, activation="relu", padding="same")(x7)
x7 = Conv2D(13, 6, activation="softmax", padding="same")(x7)



model = Model(inp, x7)

opt = Adam(lr=0.0001)
model.compile(optimizer=opt,
             loss="categorical_crossentropy",
             metrics=["accuracy"])
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 200, 256, 3)  0
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 200, 256, 3)  12          input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 200, 256, 64) 27712       batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 200, 256, 128 1179776     conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 100, 128, 128 0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 100, 128, 128 1327232     max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 100, 128, 128 1327232     conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 50, 64, 128)  0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 50, 64, 128)  589952      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 50, 64, 128)  589952      conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 25, 32, 128)  0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 25, 32, 128)  147584      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 25, 32, 128)  147584      conv2d_7[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 50, 64, 128)  0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 50, 64, 256)  0           conv2d_6[0][0]
#                                                                  up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 50, 64, 128)  1179776     concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 50, 64, 128)  589952      conv2d_9[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 100, 128, 128 0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 100, 128, 256 0           conv2d_4[0][0]
#                                                                  up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 100, 128, 128 1179776     concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 100, 128, 128 589952      conv2d_11[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 200, 256, 128 0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 200, 256, 256 0           conv2d_2[0][0]
#                                                                  up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 200, 256, 13) 119821      concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 200, 256, 13) 6097        conv2d_13[0][0]
# ==================================================================================================
# Total params: 9,002,410
# Trainable params: 9,002,404
# Non-trainable params: 6
# __________________________________________________________________________________________________

# %%
train_gen = Generate()
val_gen = Generate(val_path)

# %%
clb = [ModelCheckpoint("loss.h5", save_best_only=True, verbose=0)]

h = model.fit_generator(train_gen, epochs=25, steps_per_epoch=5,
                       validation_data=val_gen, validation_steps=5,
                       callbacks=clb, verbose=0)

# %%
model.save("model.h5")
model = load_model("loss.h5")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-12e82b5f36bd> in <module>()
# ----> 1 model.save("model.h5")
#       2 model = load_model("loss.h5")
#
# NameError: name 'model' is not defined

# %%
loss = h.history["val_loss"]
acc = h.history["val_accuracy"]

plot.figure(figsize=(12, 6))
plot.subplot(211)
plot.title("Val. Loss")
plot.plot(loss)
plot.xlabel("Epoch")
plot.ylabel("Loss")

plot.subplot(212)
plot.title("Val. Accuracy")
plot.plot(acc)
plot.xlabel("Epoch")
plot.ylabel("Accuracy")

plot.tight_layout()
plot.savefig("learn.png", dpi=150)
plot.show()

# %%
test_gen = Generate(val_path)
max_show=20
for imgs, segs in test_gen:
    p = model.predict(imgs)
    for i in range(p.shape[0]):
        if i > max_show:
            break
        _p = LayersToRGBImage(p[i])
        _s = LayersToRGBImage(segs[i])
        
        predimg = cv2.addWeighted(imgs[i], 0.6, _p, 0.4, 0)
        trueimg = cv2.addWeighted(imgs[i], 0.6, _s, 0.4, 0)
        plot.figure(figsize=(12,6))
        plot.subplot(121)
        plot.title("Prediction")
        plot.imshow(predimg)
        plot.axis("off")
        plot.subplot(122)
        plot.title("True")
        plot.imshow(trueimg)
        plot.axis("off")
        plot.tight_layout()
        plot.savefig("pred_"+str(i)+".png", dpi=150)
        plot.show()
    break

# %%
from sklearn.metrics import roc_curve, balanced_accuracy_score
test_gen = Generate(val_path, batch_size=1)
max_show=20

bass = []

for imgs, segs in test_gen:
    p = model.predict(imgs)
    
    plot.figure(figsize=(10, 10))
    for i in range(p.shape[-1]):
        fpr, tpr, _ = roc_curve(segs[:,:,:,i].ravel(), p[:,:,:,i].ravel())
        
        _p = np.round(p[:,:,:,i].ravel()).astype(np.int32)
        bas = balanced_accuracy_score(segs[:,:,:,i].ravel(), _p)
        
        bass.append(bas)
        
        plot.subplot(4,4,i+1)
        plot.plot(fpr, tpr)
        plot.title("Class "+str(i))
        plot.xlabel("False positive rate")
        plot.ylabel("True positive rate")
    
    plot.tight_layout()
    plot.show()
    
    break

# %%
plot.figure(figsize=(8, 5))
plot.bar(np.arange(0, len(bass)), bass)
plot.xticks(np.arange(0, len(bass)))
plot.ylabel("Balanced Accuracy")
plot.xlabel("Class")
plot.tight_layout()
plot.savefig("bas.png")
plot.show()
